# %%
print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4697f3e01b6> in <cell line: 1>()
# ----> 1 printf("Hello")
#
# NameError: name 'printf' is not defined
